# %%
import pandas

# %%
df = pandas.read_csv('/export/home/9hmoelle/infhome/mp-2022-clone/dnn/implementation/out/Dataframes/Dataframe,max_seconds=7,f_bi=false,t_bi=true,stft_shift=256.csv')

# %%
df.mean()
# Out:
# Unnamed: 0       296.500000
# data_index       302.703704
# SNR               -2.301735
# SISDR             13.349231
# PESQ               1.057161
# Reverberation      0.439374
# DisToNoise         1.304102
# dtype: float64

# %%
df.plot.scatter(x='SNR',y='PESQ', c='DarkBlue')
# Out:
# <AxesSubplot: xlabel='SNR', ylabel='PESQ'>

# %%
df.plot.scatter(x='Reverberation',y='PESQ', c='DarkBlue')
# Out:
# <AxesSubplot: xlabel='Reverberation', ylabel='PESQ'>

# %%
df.plot.scatter(x='DisToNoise',y='PESQ', c='DarkBlue')
# Out:
# <AxesSubplot: xlabel='DisToNoise', ylabel='PESQ'>
